// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания
// Вариант 4

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Product в C#, который будет представлять информацию о
// продуктах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма.
// В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// Требования к базовому классу Product:
//
// • Атрибуты: Название (Name), Цена (Price), Производитель (Manufacturer).
//
// • Методы:
//
// o GetInfo(): метод для получения информации о продукте в виде строки.
//
// o Discount(): метод для применения скидки к цене продукта.
//
// o Display(): метод для отображения информации о продукте на экране.
//
// Требования к производным классам:
// 1. Электроника (Electronics): Должен содержать дополнительные атрибуты,
// такие как Гарантийный срок (WarrantyPeriod). Метод Discount() должен быть
// переопределен для добавления логики учета гарантийного срока при
// применении скидки.
// 2. Одежда (Clothing): Должен содержать дополнительные атрибуты, такие как
// Размер (Size). Метод Display() должен быть переопределен для добавления
// информации о размере при отображении информации о продукте.
// 3. Книги (Books) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Автор (Author). Метод GetInfo() должен
// быть переопределен для включения информации об авторе в описании
// продукта.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Product
{
    
    private string name; 
    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    private string manufacturer; 
    public string Manufacturer
    {
        get { return manufacturer; }
        set { manufacturer = value; }
    }

    private double price; 
    public double  Price
    {
        get { return price; }
        set { price = value; }
    }

    public double OldPrice;
    public double NewPrice;

    public virtual void GetInfo()
    {
        Console.WriteLine($"Информация о продукте: название: {Name}, цена: {Price}, производитель: {Manufacturer}");
    }

    public virtual void Discount(double sale)
    {
        OldPrice = Price;
        NewPrice = Price - Price * (sale / 100);
        Console.WriteLine($"Сделана скидка {sale}%: старая цена: {OldPrice}, новая цена: {NewPrice}");
        Price = NewPrice;
    }

    public virtual void Display()
    {
        Console.WriteLine("Информация о продукте:");
        Console.WriteLine($"  Название: {Name}");
        Console.WriteLine($"  Цена: {Price}");
        Console.WriteLine($"  Фабрика-производитель: {Manufacturer}");
    }
}


public class Electronics : Product
{
    private int warrantyPeriod; 
    public int WarrantyPeriod
    {
        get { return warrantyPeriod; }
        set { warrantyPeriod = value; }
    }

    public override void Discount(double sale)
    {
        
        if (WarrantyPeriod < 12)
        {
            sale += 5; 
        }
        base.Discount(sale);
    }

}


public class Clothing : Product
{
    private int size; 
    public int Size
    {
        get { return size; }
        set { size = value; }
    }
    public override void Display()
    {
        base.Display();
        Console.WriteLine($"Размер: {Size}");
    }
}


public class Books : Product
{
    private string author;
    public string Author
    {
        get { return author; }
        set { author = value; }
    }

    public override void GetInfo()
    {
        base.GetInfo();
        Console.WriteLine($"Автор: {Author}");
    }
}



Product phone = new Electronics
{
    Name = "телефон",
    Price = 12000,
    Manufacturer = "Nokia",
    WarrantyPeriod = 6
};

Product dress = new Clothing
{
    Name = "платье",
    Price = 2000,
    Manufacturer = "Ивановский трикотаж",
    Size = 48
};

Product book = new Books
{
    Name = "Война и мир",
    Price = 3000,
    Manufacturer = "Эксмо",
    Author = "Л. Толстой"
};

phone.Display();
phone.Discount(10);
phone.GetInfo();

dress.Display();
dress.Discount(15);
dress.GetInfo();

book.Display();
book.Discount(10);
book.GetInfo();
// Out:
// Информация о продукте:
//   Название: телефон
//   Цена: 12000
//   Фабрика-производитель: Nokia
// Сделана скидка 15%: старая цена: 12000, новая цена: 10200
// Информация о продукте: название: телефон, цена: 10200, производитель: Nokia
// Информация о продукте:
//   Название: платье
//   Цена: 2000
//   Фабрика-производитель: Ивановский трикотаж
// Размер: 48
// Сделана скидка 15%: старая цена: 2000, новая цена: 1700
// Информация о продукте: название: платье, цена: 1700, производитель: Ивановский трикотаж
// Информация о продукте:
//   Название: Война и мир
//   Цена: 3000
//   Фабрика-производитель: Эксмо
// Сделана скидка 10%: старая цена: 3000, новая цена: 2700
// Информация о продукте: название: Война и мир, цена: 2700, производитель: Эксмо
// Автор: Л. Толстой
